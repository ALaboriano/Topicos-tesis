# %% [markdown]
# # 1. Configuraciones

# %%
# Características de la MV
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# Declarar variables
HOME ="/content/drive/MyDrive/Maestria/Tesis/DFL-BundesligaDataShootout/Experimentacion"
HOME
# Out:
# '/content/drive/MyDrive/Maestria/Tesis/DFL-BundesligaDataShootout/Experimentacion'

# %% [markdown]
# # 2. Conectarse a drive

# %%
# Conectarse a drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Establecer directorio de trabajo
# %cd {HOME}
# Out:
# /content/drive/MyDrive/Maestria/Tesis/DFL-BundesligaDataShootout/Experimentacion

# %%
# !ls -l
# Out:
# total 1
# -rw------- 1 root root 920 Mar  4 15:22 DFL-BundesligaDataSootout.ipynb

# %% [markdown]
# # 3. Descargar data

# %%
# Leer data del reto de Kaggle, id_imagen y clasificación
# más info en: https://www.analyticsvidhya.com/blog/2021/06/how-to-load-kaggle-datasets-directly-into-google-colab/
! pip install kaggle
! mkdir ~/.kaggle
! cp /content/drive/MyDrive/Kaggle/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Crear carpeta donde se almacenará la data y setear como directorio temporal.
# !mkdir data
# %cd {HOME}/"data"

# %%
# %%time
# Descargar data
# !kaggle competitions download -c dfl-bundesliga-data-shootout
# Out:
# ...
# 100% 34.9G/34.9G [05:12<00:00, 161MB/s]
# 100% 34.9G/34.9G [05:12<00:00, 120MB/s]
# CPU times: user 6.36 s, sys: 975 ms, total: 7.34 s
# Wall time: 5min 14s

# %%
# Peso del archivo descargado
# https://www.sysadmit.com/2017/09/linux-saber-tamano-directorio.html
# !du  -h *
# Out:
# 35G	dfl-bundesliga-data-shootout.zip

# %%
# %%time
# Descomprimir archivo, eliminar el zip descargado y volver al directorio principal.
# !unzip {HOME}/data/dfl-bundesliga-data-shootout.zip 
# !rm {HOME}/data/dfl-bundesliga-data-shootout.zip
# %cd {HOME}
# Out:
# Archive:  /content/drive/MyDrive/Maestria/Tesis/DFL-BundesligaDataShootout/Experimentacion/data/dfl-bundesliga-data-shootout.zip
#   inflating: clips/08fd33_0.mp4
#   inflating: clips/08fd33_1.mp4
#   inflating: clips/08fd33_2.mp4
#   inflating: clips/08fd33_3.mp4
#   inflating: clips/08fd33_4.mp4
#   inflating: clips/08fd33_5.mp4
#   inflating: clips/08fd33_6.mp4
#   inflating: clips/08fd33_7.mp4
#   inflating: clips/08fd33_8.mp4
#   inflating: clips/08fd33_9.mp4
#   inflating: clips/0a2d9b_0.mp4
#   inflating: clips/0a2d9b_1.mp4
#   inflating: clips/0a2d9b_2.mp4
#   inflating: clips/0a2d9b_3.mp4
#   inflating: clips/0a2d9b_4.mp4
#   inflating: clips/0a2d9b_5.mp4
#   inflating: clips/0a2d9b_6.mp4
#   inflating: clips/0a2d9b_7.mp4
#   inflating: clips/0a2d9b_8.mp4
#   inflating: clips/0a2d9b_9.mp4
#   inflating: clips/0bfacc_0.mp4
#   inflating: clips/0bfacc_1.mp4
#   inflating: clips/0bfacc_2.mp4
#   inflating: clips/0bfacc_3.mp4
#   inflating: clips/0bfacc_4.mp4
# ...

# %%
# !du -h
# Out:
# 3.7G	./data/clips
# 620M	./data/test
# 31G	./data/train
# 35G	./data
# 35G	.
